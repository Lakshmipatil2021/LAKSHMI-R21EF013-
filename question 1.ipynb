# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
student_df = pd.read_csv("C:/Users/drkir/Downloads/Student_Enrollment_for_Regular_courses-2015.csv")
student_df
# Out:
#        University_id                                    University_name  \
# 0                774                                     DIT UNIVERSITY
# 1                594                   Children University, Gandhinagar
# 2                708                 C.U.SHAH UNIVERSITY, SURENDRANAGAR
# 3                702  SHREE GURU GOBIND SINGH TRICENTENARY UNIVERSIT...
# 4                140                   Junagadh Agricultural University
# ...              ...                                                ...
# 68012            399                Jai Narain Vyas University, Jodhpur
# 68013            173            O. P. Jindal Global University, Sonipat
# 68014            162  Guru Jambheshwar University of Science and Tec...
# 68015            162  Guru Jambheshwar University of Science and Tec...
# 68016            201           Shri Mata Vaishno Devi University, Jammu
#
#        survey_year                                       faculty_name  \
# ...

# %%
student_df.tail()
# Out:
#        University_id                                    University_name  \
# 68012            399                Jai Narain Vyas University, Jodhpur
# 68013            173            O. P. Jindal Global University, Sonipat
# 68014            162  Guru Jambheshwar University of Science and Tec...
# 68015            162  Guru Jambheshwar University of Science and Tec...
# 68016            201           Shri Mata Vaishno Devi University, Jammu
#
#        survey_year                      faculty_name  \
# 68012         2015  Faculty of Commerce & Management
# 68013         2015          Jindal Global Law School
# 68014         2015        Haryana School of Business
# 68015         2015        Haryana School of Business
# 68016         2015            Faculty of Engineering
#
#                                     department_name          levell  \
# 68012                                           NaN  Under Graduate
# 68013                                           NaN      Integrated
# ...

# %%
student_df.head()
# Out:
#    University_id                                    University_name  \
# 0            774                                     DIT UNIVERSITY
# 1            594                   Children University, Gandhinagar
# 2            708                 C.U.SHAH UNIVERSITY, SURENDRANAGAR
# 3            702  SHREE GURU GOBIND SINGH TRICENTENARY UNIVERSIT...
# 4            140                   Junagadh Agricultural University
#
#    survey_year                                       faculty_name  \
# 0         2015                  Faculty of Science and Technology
# 1         2015                                           Research
# 2         2015  Faculty of Technology & Engineering / C. U. Sh...
# 3         2015              Faculty of Medicine & Health Sciences
# 4         2015                                                NaN
#
#      department_name          levell  programme_id  \
# 0  Civil Engineering  Under Graduate            36
# 1                NaN           Ph.D.           157
# ...

# %%
student_df.nunique()
# Out:
# University_id                       706
# University_name                     706
# survey_year                           1
# faculty_name                       2061
# department_name                    3103
# levell                                8
# programme_id                        172
# programme                           172
# discipline_group_id                 174
# discipline_group                    174
# discipline                         9709
# type                                  3
# year                                  7
# total_general_total                 505
# total_general_females               295
# total_sc_total                      229
# total_sc_females                    116
# total_st_total                      121
# total_st_females                     83
# total_obc_total                     351
# total_obc_females                   198
# total_total_persons                 699
# total_total_females                 396
# ...

# %%
student_df.duplicated().sum()
# Out:
# 284

# %%
df=student_df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
student_df.isna().sum()
# Out:
# University_id                          0
# University_name                        0
# survey_year                            0
# faculty_name                        5145
# department_name                    35822
# levell                                 0
# programme_id                           0
# programme                              0
# discipline_group_id                    0
# discipline_group                       0
# discipline                            10
# type                                   0
# year                                7414
# total_general_total                 8114
# total_general_females               8114
# total_sc_total                      8114
# total_sc_females                    8114
# total_st_total                      8114
# total_st_females                    8114
# total_obc_total                     8177
# total_obc_females                   8177
# total_total_persons                    0
# total_total_females                    0
# ...

# %%
student_df.tail()
# Out:
#        University_id                                    University_name  \
# 68012            399                Jai Narain Vyas University, Jodhpur
# 68013            173            O. P. Jindal Global University, Sonipat
# 68014            162  Guru Jambheshwar University of Science and Tec...
# 68015            162  Guru Jambheshwar University of Science and Tec...
# 68016            201           Shri Mata Vaishno Devi University, Jammu
#
#        survey_year                      faculty_name  \
# 68012         2015  Faculty of Commerce & Management
# 68013         2015          Jindal Global Law School
# 68014         2015        Haryana School of Business
# 68015         2015        Haryana School of Business
# 68016         2015            Faculty of Engineering
#
#                                     department_name          levell  \
# 68012                                           NaN  Under Graduate
# 68013                                           NaN      Integrated
# ...

# %%
df.loc[0,'University_name']
# Out:
# 'DIT UNIVERSITY'

# %%
df.fillna
# Out:
# <bound method DataFrame.fillna of        University_id                                    University_name  \
# 0                774                                     DIT UNIVERSITY
# 1                594                   Children University, Gandhinagar
# 2                708                 C.U.SHAH UNIVERSITY, SURENDRANAGAR
# 3                702  SHREE GURU GOBIND SINGH TRICENTENARY UNIVERSIT...
# 4                140                   Junagadh Agricultural University
# ...              ...                                                ...
# 68012            399                Jai Narain Vyas University, Jodhpur
# 68013            173            O. P. Jindal Global University, Sonipat
# 68014            162  Guru Jambheshwar University of Science and Tec...
# 68015            162  Guru Jambheshwar University of Science and Tec...
# 68016            201           Shri Mata Vaishno Devi University, Jammu
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 67733 entries, 0 to 68016
# Data columns (total 57 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   University_id                    67733 non-null  int64
#  1   University_name                  67733 non-null  object
#  2   survey_year                      67733 non-null  int64
#  3   faculty_name                     62686 non-null  object
#  4   department_name                  32130 non-null  object
#  5   levell                           67733 non-null  object
#  6   programme_id                     67733 non-null  int64
#  7   programme                        67733 non-null  object
#  8   discipline_group_id              67733 non-null  int64
#  9   discipline_group                 67733 non-null  object
#  10  discipline                       67723 non-null  object
#  11  type                             67733 non-null  object
# ...

# %%
df.shape
# Out:
# (67733, 57)

# %%
df.columns
# Out:
# Index(['University_id', 'University_name', 'survey_year', 'faculty_name',
#        'department_name', 'levell', 'programme_id', 'programme',
#        'discipline_group_id', 'discipline_group', 'discipline', 'type', 'year',
#        'total_general_total', 'total_general_females', 'total_sc_total',
#        'total_sc_females', 'total_st_total', 'total_st_females',
#        'total_obc_total', 'total_obc_females', 'total_total_persons',
#        'total_total_females', 'total_remarks_id', 'pwd_general_total',
#        'pwd_general_females', 'pwd_sc_total', 'pwd_sc_females', 'pwd_st_total',
#        'pwd_st_females', 'pwd_obc_total', 'pwd_obc_females',
#        'pwd_total_persons', 'pwd_total_females', 'pwd_remarks_id',
#        'muslim_minority_general_total', 'muslim_minority_general_females',
#        'muslim_minority_sc_total', 'muslim_minority_sc_females',
#        'muslim_minority_st_total', 'muslim_minority_st_females',
# ...
