# %%
import pandas as pd
df = pd.read_csv('C:/Users/drkir/Downloads/california_housing_sklearn.csv')

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  SalePrice
# ...

# %%
#data analysis with virtualization
import matplotlib.pyplot as plt
import seaborn as sns
plt.hist(df['AveRooms'], bins=30, color='skyblue')
plt.title('Distribution of Numerical Column')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Explicitly set numeric_only to True to silence the FutureWarning
correlation_matrix = df.corr(numeric_only=True)

# Create a heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
import pandas as pd

# Define or read the DataFrame from a file
df = pd.read_csv('C:/Users/drkir/Downloads/california_housing_sklearn.csv')

# Continue with the rest of your code
correlation_matrix = df.corr(numeric_only=True)
import seaborn as sns
import matplotlib.pyplot as plt

# Explicitly set numeric_only to True to silence the FutureWarning
correlation_matrix = df.corr(numeric_only=True)

# Create a heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
plt.scatter(df.HouseAge,df.Population)
plt.xlabel('HouseAge')
plt.ylabel('Population')
# Out:
# Text(0, 0.5, 'Population')

# %%
df['HouseAge'].value_counts().plot(kind='bar')
plt.xlabel('MedInc')
plt.ylabel('AveRooms')
sns.despine()

# %%
sns.scatterplot(data=df, x='MedInc', y='SalePrice', hue='AveRooms')
plt.show()

# %%
cat_var = ['MedInc','HouseAge','AveRooms','AveBedrms']
num_var = ['Latitude','SalePrice']

# %%
for column in cat_var:   
    plt.figure(figsize=(12,5))
    plt.subplot(1,2,1)
    ax = sns.countplot(x=column, data=df, palette='Accent')
    ax.bar_label(ax.containers[0])
    plt.show()

# %%
for column in cat_var:
    plt.subplot(1,2,2)
    ax = sns.countplot(x=column, data=df, hue='MedInc', palette='Accent')
    ax.bar_label(ax.containers[0])
    ax.bar_label(ax.containers[1])
    plt.show()
